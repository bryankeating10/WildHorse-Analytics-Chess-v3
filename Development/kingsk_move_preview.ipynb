# %% [markdown]
# # **Preview of kingsk4 Move Data**

# %%
import pandas as pd

df_moves = pd.read_csv('../Data/Gold/kingsk4_moves_gold.csv')

# %% [markdown]
# First move tendencies

# %%
first_move = df_moves[df_moves['ply'] == 1]
print(first_move.value_counts('move'))
# Out:
# move
# d4     2161
# e4     1748
# e3      111
# Nf3      69
# b3       30
# g3       30
# d3       29
# c4       28
# Nc3      20
# h4       11
# c3       10
# f4        8
# a3        7
# a4        5
# h3        4
# f3        4
# g4        3
# Nh3       2
# b4        1
# Name: count, dtype: int64
